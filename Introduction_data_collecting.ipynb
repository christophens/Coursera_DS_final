# %% [markdown]
# # Introduction
#
# This is the first of two notebooks related to the Applied Data Science Capstone project. This notebook contains a short presentation of the problem, the methodology as well as all steps that are required to collect the data. The second notebook contains all the data exploration, modelling and evaluation steps.
#
# # Problem definition
#
# In this project we set out to build a model that predicts the number of bike shops in a zip code area in New York City. We'll use this information to give a recommendation on where to open a bike shop. This recommendation is based on the difference between existing and predicted number of bike shops. Our model leverages foursquare data, data from the American Community Census as well as other data sources.
#
#
# # Data collecting
#
# We start by importing the necessary libraries.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import folium
import json, requests
from uszipcode import SearchEngine
import ast
import itertools
from itertools import chain, combinations


# Plotting tools
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Evaluation and models
from sklearn import preprocessing
from sklearn import model_selection
from sklearn import linear_model
from sklearn import metrics
import scipy
import statistics

# %% [markdown]
# We start by downloading a geojson file that contains all zip codes in the state of New York. This provides us with a complete list of zip codes as well as a possibility to visualize results on a folium map.

# %%
#Download the GeoJSON file
# !wget document --output-document=ny_geo.json -nc https://github.com/OpenDataDE/State-zip-code-GeoJSON/raw/master/ny_new_york_zip_codes_geo.min.json
# Out:
# Die Datei »ny_geo.json« ist schon vorhanden; kein erneuter Download.

# %% [markdown]
# After extracting a list of all zip codes in the state of New York we use the uszipcode library to filter out those zip codes that belong to New York City and at latitude and longitude information. We find 211 zip codes

# %%
# Extract all postal codes that belong to the NYC area
# Open the file
ny_geojson_filename = 'ny_geo.json'
with open(ny_geojson_filename) as f:
    data = json.load(f)

# Build the basic dataframe and define NYC counties
ny_df = pd.DataFrame(columns = ['Zip Code', 'County', 'Lat', 'Long', 'Area'])
nyc_counties_set = ('New York County', 'Bronx County', 'Queens County', 'Kings County', 'Richmond County')

# Get a search object from the uszipcode library
search = SearchEngine(simple_zipcode = False)

# Loop over the geojson 
for r in data['features']:
    
    # Use the search object to get information related to the zip codes
    a = search.by_zipcode(r['properties']['ZCTA5CE10'])
    
    # Get a list from the returned object
    a = a.values()
    
    # If the zip code belongs to NYC, add all the information to the dataframe
    if a[4] in nyc_counties_set:
        ny_df = ny_df.append({'Zip Code':r['properties']['ZCTA5CE10'], 'County': a[4],
                              'Lat': a[6], 'Long': a[7], 'Area': a[13]}, ignore_index = True)

# %%
print("Rows in the dataframe: " + str(max(ny_df.shape)))
ny_df.head()
# Out:
# Rows in the dataframe: 211
#   Zip Code        County    Lat   Long  Area
# 0    10464  Bronx County  40.86 -73.79  3.50
# 1    10470  Bronx County  40.90 -73.86  1.42
# 2    10455  Bronx County  40.81 -73.91  0.71
# 3    10473  Bronx County  40.82 -73.86  2.18
# 4    11234  Kings County  40.61 -73.89  7.55

# %% [markdown]
# ## Foursquare API calls
#
# The next cells contain all tasks required to extract a list of unique bike shops and relate them to their respective zip codes. The first of the two functions below is used to build a API-call url based on a set of keywords.
# The second function returns a list of unique locations. We need this second function because the foursquare API does not directly allow us to specify a zip code area, but rather uses latitude and longitude information. We therefore call the foursquare api using the zip code latitude and longitude. After that, we map the results to a zip code area and discard any duplicate entries.

# %%
# This cell defines two functions that we use to simplify the Foursquare API calls

def foursquare_url(endpoint, **kwargs):
    # This function constructs a url that can be used to make an call to the Foursquare API.
    
    # Foursquare Login Credentials
    foursquare_id_client = ''
    foursquare_id_secret = ''
    foursquare_id_version = ''   
    
    # Construct base url with selected api endpoint and authentication credentials
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
        endpoint, foursquare_id_client, foursquare_id_secret, foursquare_id_version) 

    if endpoint == 'search':
        # Search Keywords: 'radius', 'query', 'limit', 'latitude', 'longitude', 'near', 'categoryId'
        coordinates_flag = False
        near_flag = False
        for key, value in kwargs.items():
            # Handle simple keys: radius, query and limit
            if key in {'radius', 'query', 'limit'}:
                url = url + '&{}={}'.format(key, value)
            # Handle coordinate keys: If one of either is found 
            # and no coordinates have yet been added
            elif (key == 'latitude' or key == 'longitude'):
                # check if no near information has been provided
                if not near_flag and not coordinates_flag:
                    # Check if arguments contain both lat and long information, then add them to
                    # url and set the coordinate flag to True
                    if 'latitude' in kwargs and 'longitude' in kwargs:
                        url = url + '&ll={},{}'.format(kwargs.get('latitude'), kwargs.get('longitude'))
                        coordinates_flag = True
                    # Raise exception if either keyword is corrupted or missing
                    else:
                        print('Error with entering coordinates')
                        return
                # Raise exception if keywords contain both coordinates and near information
                elif near_flag:
                    print('Coordinates and near a location used simultaneously.')
                    return
            # Handle near key: If a near key has been provided and no coordinates were entered
            elif key == 'near':
                # Check if no coordinates were entered yet, then add near parameter to url
                # and set near_flag to true 
                if not coordinates_flag:   
                    url = url + '&{}={}'.format(key, value)
                    near_flag = True
                # Raise exception if keywords contain both coordinates and near information
                else:
                    print('Coordinates and near a location used simultaneously.')
                    return
            elif key == 'categoryId':
                Id_string = ",".join(value)
                url = url + '&{}={}'.format(key, Id_string)
            else:
                print('Wrong key: ' + key)
                return
    return url

def search_foursquare(location_df,idlist):
    # This function is used to build a dictionairy containing unique locations. It takes a dataframe with latitude
    # and longitude information as well as a list of desired category ids and returns a dict that contains
    # unique venues, with the key being the venue id and the value being the rest of the information returned
    # by the foursquare API. 
    
    # Initialize empty dict
    results_dict = {}
    # Loop over the different ids
    for id in idlist:
        #Loop over the dataframe
        for index, row in location_df.iterrows():
            # Use the above function to construct the url
            search_url = foursquare_url('search', latitude = row['Lat'], longitude = row['Long'], 
                                   radius = 2000, categoryId = [id])
            # Make API call
            response = requests.get(search_url).json()
            # Check if call returned any venues
            if response['response']['venues']:
                # Loop over result list
                for result in response['response']['venues']:
                    # Check if venue has already been added to the dict
                    if result['id'] not in results_dict:
                        # Add entry to result_dict in the form of {'id':{key:value for all other information}}
                        results_dict[result['id']] = {i:result[i] for i in result if i!='id'}
    # Return the resulting dict
    return results_dict

# %%
# Call the above functions to get a dict with all bike shops in NYC
bikeshops_dict = search_foursquare(ny_df, ['4bf58dd8d48988d115951735'])

# %% [markdown]
# Using the method described above we find 370 unique bike shops.

# %%
# We find 370 unique bike shops
print("Number of unique bike shops: " + str(len(bikeshops_dict)))
bikeshops_dict
# Out:
# Number of unique bike shops: 373
# {'4bd7372b0b779c74f8ad04a0': {'name': 'County Cycle Center',
#   'location': {'address': '970 McLean Ave',
#    'crossStreet': 'Martha Avenue',
#    'lat': 40.903306,
#    'lng': -73.865639,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.903306,
#      'lng': -73.865639},
#     {'label': 'entrance', 'lat': 40.903177, 'lng': -73.865683}],
#    'distance': 600,
#    'postalCode': '10704',
#    'cc': 'US',
#    'city': 'Yonkers',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['970 McLean Ave (Martha Avenue)',
#     'Yonkers, NY 10704',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718037',
#   'hasPerk': False},
#  '50608454e4b0fc173099b6d5': {'name': 'Bronx River Bicycle Works',
#   'location': {'address': '27 Mount Vernon Avenue Second Floor',
#    'lat': 40.911275,
#    'lng': -73.84504799999999,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.911275,
#      'lng': -73.84504799999999},
#     {'label': 'entrance', 'lat': 40.911149, 'lng': -73.845122}],
#    'distance': 1777,
#    'postalCode': '10550',
#    'cc': 'US',
#    'city': 'Mount Vernon',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['27 Mount Vernon Avenue Second Floor',
#     'Mount Vernon, NY 10550',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '434506491'},
#   'referralId': 'v-1598718037',
#   'hasPerk': False},
#  '4bf5525594af2d7fb78c3b72': {'name': "Kim's Motorcycle Corp",
#   'location': {'address': '855 McLean Ave',
#    'lat': 40.90551,
#    'lng': -73.870253,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.90551,
#      'lng': -73.870253}],
#    'distance': 1058,
#    'postalCode': '10704',
#    'cc': 'US',
#    'city': 'Yonkers',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['855 McLean Ave',
#     'Yonkers, NY 10704',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718037',
#   'hasPerk': False},
#  '511fd14be4b0b9b40101898a': {'name': 'bike shop',
#   'location': {'lat': 40.88997268676758,
#    'lng': -73.85940551757812,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.88997268676758,
#      'lng': -73.85940551757812}],
#    'distance': 1117,
#    'postalCode': '10466',
#    'cc': 'US',
#    'city': 'Bronx',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['Bronx, NY 10466', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718037',
#   'hasPerk': False},
#  '4d60403aef378cfaf9147ba6': {'name': 'Arrow Cycle Inc',
#   'location': {'address': '4057 White Plains Rd',
#    'lat': 40.8901573839872,
#    'lng': -73.8594140338906,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.8901573839872,
#      'lng': -73.8594140338906}],
#    'distance': 1096,
#    'postalCode': '10466',
#    'cc': 'US',
#    'city': 'Bronx',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['4057 White Plains Rd',
#     'Bronx, NY 10466',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718037',
#   'hasPerk': False},
#  '5b5ca5861acf11002c3174bb': {'name': 'Cruz Bike Shop',
#   'location': {'lat': 40.808537,
#    'lng': -73.922027,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.808537,
#      'lng': -73.922027}],
#    'distance': 1026,
#    'postalCode': '10454',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['New York, NY 10454', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4d03abeb37036dcb01900bfb': {'name': 'Neighborhood Cycle',
#   'location': {'address': '571 Courtlandt Ave',
#    'crossStreet': 'E 150th St',
#    'lat': 40.817156,
#    'lng': -73.919534,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.817156,
#      'lng': -73.919534},
#     {'label': 'entrance', 'lat': 40.817138, 'lng': -73.919395}],
#    'distance': 1131,
#    'postalCode': '10451',
#    'cc': 'US',
#    'city': 'Bronx',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['571 Courtlandt Ave (E 150th St)',
#     'Bronx, NY 10451',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4c912197ae45224b3240e597': {'name': 'Master Cycle',
#   'location': {'address': '3 Bruckner Blvd',
#    'lat': 40.807835979812964,
#    'lng': -73.93060027914952,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.807835979812964,
#      'lng': -73.93060027914952},
#     {'label': 'entrance', 'lat': 40.808208, 'lng': -73.930366}],
#    'distance': 1752,
#    'postalCode': '10454',
#    'cc': 'US',
#    'city': 'Bronx',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['3 Bruckner Blvd',
#     'Bronx, NY 10454',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '54458271498e45bb96dc877b': {'name': 'Bronx Cycles',
#   'location': {'address': '112 E 157th Street',
#    'lat': 40.82530975341797,
#    'lng': -73.92639923095703,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.82530975341797,
#      'lng': -73.92639923095703}],
#    'distance': 2193,
#    'postalCode': '10451',
#    'cc': 'US',
#    'city': 'Bronx',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['112 E 157th Street',
#     'Bronx, NY 10451',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4fa59e6ee4b0cfe54d1b3bb5': {'name': 'Shorehaven Bike',
#   'location': {'lat': 40.80764429921407,
#    'lng': -73.85407890373678,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.80764429921407,
#      'lng': -73.85407890373678}],
#    'distance': 1463,
#    'postalCode': '10473',
#    'cc': 'US',
#    'city': 'Bronx',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['Bronx, NY 10473', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4b9b00baf964a520deea35e3': {'name': 'Castle Hill Toys & Games',
#   'location': {'address': '1375 Castle Hill Ave',
#    'lat': 40.835722,
#    'lng': -73.852407,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.835722,
#      'lng': -73.852407},
#     {'label': 'entrance', 'lat': 40.835759, 'lng': -73.852276}],
#    'distance': 1863,
#    'postalCode': '10462',
#    'cc': 'US',
#    'city': 'Bronx',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['1375 Castle Hill Ave',
#     'Bronx, NY 10462',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4f9ac399e4b07e720c6ed176': {'name': 'westchester Toys * Bikes',
#   'location': {'lat': 40.828712463378906,
#    'lng': -73.877685546875,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.828712463378906,
#      'lng': -73.877685546875}],
#    'distance': 1777,
#    'postalCode': '10472',
#    'cc': 'US',
#    'city': 'Bronx',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['Bronx, NY 10472', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4b4c120af964a520e4ad26e3': {'name': "Larry's Cycle Shop",
#   'location': {'address': '1854 Flatbush Ave',
#    'lat': 40.624390999999996,
#    'lng': -73.939196,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.624390999999996,
#      'lng': -73.939196},
#     {'label': 'entrance', 'lat': 40.624472, 'lng': -73.939064}],
#    'distance': 1105,
#    'postalCode': '11210',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['1854 Flatbush Ave',
#     'Brooklyn, NY 11210',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4c6d9ef006ed6dcbde6ba422': {'name': 'Two Friends',
#   'location': {'address': '658A E 3rd St',
#    'crossStreet': 'Ditmas Avenue',
#    'lat': 40.63603346689502,
#    'lng': -73.97597522179888,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.63603346689502,
#      'lng': -73.97597522179888}],
#    'distance': 2294,
#    'postalCode': '11218',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['658A E 3rd St (Ditmas Avenue)',
#     'Brooklyn, NY 11218',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4bb4cd75bc82a593ced83e72': {'name': 'Brooklyn Bicycle Center',
#   'location': {'address': '673 Coney Island Ave',
#    'crossStreet': 'Ave C.',
#    'lat': 40.641032,
#    'lng': -73.969024,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.641032,
#      'lng': -73.969024},
#     {'label': 'entrance', 'lat': 40.641019, 'lng': -73.969127}],
#    'distance': 2022,
#    'postalCode': '11218',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['673 Coney Island Ave (Ave C.)',
#     'Brooklyn, NY 11218',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4bf443d8cad2c9288bb89b99': {'name': 'City Cycles',
#   'location': {'address': '2079 Utica Ave',
#    'crossStreet': 'Ave M',
#    'lat': 40.622498855613294,
#    'lng': -73.9272304567357,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.622498855613294,
#      'lng': -73.9272304567357},
#     {'label': 'entrance', 'lat': 40.620902, 'lng': -73.926908}],
#    'distance': 2097,
#    'postalCode': '11234',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['2079 Utica Ave (Ave M)',
#     'Brooklyn, NY 11234',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4f1a7e72e4b0bf76283e75cf': {'name': 'Si  Pu Liau',
#   'location': {'address': 'Brooklyn',
#    'lat': 40.642048257868204,
#    'lng': -73.94766090007968,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.642048257868204,
#      'lng': -73.94766090007968}],
#    'distance': 1355,
#    'postalCode': '11226',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['Brooklyn', 'Brooklyn, NY 11226', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4c8cdc40c37a6dcb51bffa7a': {'name': 'Brooklyn Bike Jumble',
#   'location': {'address': '336 3rd St',
#    'crossStreet': '4th St & 5th Ave',
#    'lat': 40.67266260137063,
#    'lng': -73.98400441284429,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.67266260137063,
#      'lng': -73.98400441284429},
#     {'label': 'entrance', 'lat': 40.67305, 'lng': -73.984565}],
#    'distance': 449,
#    'postalCode': '66941',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['336 3rd St (4th St & 5th Ave)',
#     'Brooklyn, NY 66941',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4dc4124c887717c87fffab35': {'name': 'Bicycle Habitat',
#   'location': {'address': '476 5th Ave',
#    'crossStreet': '11th st',
#    'lat': 40.66817748137621,
#    'lng': -73.98715881160595,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.66817748137621,
#      'lng': -73.98715881160595}],
#    'distance': 637,
#    'postalCode': '11215',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['476 5th Ave (11th st)',
#     'Brooklyn, NY 11215',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '5d910bd552f64b00085d0944': {'name': 'Recycle-A-Bicycle',
#   'location': {'address': '858 Fulton St',
#    'lat': 40.68330764770508,
#    'lng': -73.96705627441406,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.68330764770508,
#      'lng': -73.96705627441406}],
#    'distance': 1840,
#    'postalCode': '11238',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['858 Fulton St',
#     'New York, NY 11238',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4b25258df964a520dd6c24e3': {'name': '718 Cyclery',
#   'location': {'address': '254 3rd Ave',
#    'crossStreet': 'at Union St',
#    'lat': 40.6782734094982,
#    'lng': -73.98561198169334,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.6782734094982,
#      'lng': -73.98561198169334},
#     {'label': 'entrance', 'lat': 40.678205, 'lng': -73.985666}],
#    'distance': 1035,
#    'postalCode': '11215',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['254 3rd Ave (at Union St)',
#     'Brooklyn, NY 11215',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '54f8e17a498eb11d4d466975': {'name': 'Greenpath Electric Bikes',
#   'location': {'address': '757 4th Ave',
#    'lat': 40.660077,
#    'lng': -73.998009,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.660077,
#      'lng': -73.998009}],
#    'distance': 1879,
#    'postalCode': '11232',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['757 4th Ave', 'Brooklyn, NY 11232', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '444331851'},
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '56f3167a498eb2d412eb0020': {'name': 'The Bike Truck',
#   'location': {'address': '216 Hoyt St',
#    'crossStreet': 'Baltic',
#    'lat': 40.683777,
#    'lng': -73.989896,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.683777,
#      'lng': -73.989896}],
#    'distance': 1746,
#    'postalCode': '11217',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['216 Hoyt St (Baltic)',
#     'Brooklyn, NY 11217',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4b4c10f1f964a520d5ad26e3': {'name': 'Bike Shop',
#   'location': {'address': '514 Court Street',
#    'crossStreet': 'Between Nelson And Huntington',
#    'lat': 40.6762920600228,
#    'lng': -73.9988794946572,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.6762920600228,
#      'lng': -73.9988794946572}],
#    'distance': 1741,
#    'postalCode': '11231',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['514 Court Street (Between Nelson And Huntington)',
#     'Brooklyn, NY 11231',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4bca2583b6c49c74a1e28f91': {'name': 'Bike Life',
#   'location': {'address': '56 Lincoln Rd',
#    'lat': 40.660601,
#    'lng': -73.961067,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.660601,
#      'lng': -73.961067},
#     {'label': 'entrance', 'lat': 40.660743, 'lng': -73.961077}],
#    'distance': 1910,
#    'postalCode': '11225',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['56 Lincoln Rd',
#     'Brooklyn, NY 11225',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4a2c122cf964a5201a971fe3': {'name': 'On the Move',
#   'location': {'address': '259 13th St',
#    'crossStreet': 'btwn 4th & 5th Ave',
#    'lat': 40.664863000000004,
#    'lng': -73.98357,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.664863000000004,
#      'lng': -73.98357},
#     {'label': 'entrance', 'lat': 40.664818, 'lng': -73.983476}],
#    'distance': 646,
#    'postalCode': '11215',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['259 13th St (btwn 4th & 5th Ave)',
#     'Brooklyn, NY 11215',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4e41b1f9887719193960a450': {'name': 'Acme Bicycle Company',
#   'location': {'address': '353 3rd St',
#    'crossStreet': '5th Avenue',
#    'lat': 40.673169,
#    'lng': -73.98350699999999,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.673169,
#      'lng': -73.98350699999999},
#     {'label': 'entrance', 'lat': 40.673073, 'lng': -73.983602}],
#    'distance': 460,
#    'postalCode': '11217',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['353 3rd St (5th Avenue)',
#     'Brooklyn, NY 11217',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '537a6066498e86c2173b296b': {'name': 'Bicycle Habitat',
#   'location': {'address': '560 Vanderbilt Ave',
#    'crossStreet': 'Bergen',
#    'lat': 40.67991256713867,
#    'lng': -73.96839904785156,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.67991256713867,
#      'lng': -73.96839904785156}],
#    'distance': 1475,
#    'postalCode': '11238',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['560 Vanderbilt Ave (Bergen)',
#     'Brooklyn, NY 11238',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '88536392'},
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '553ece0d498e50453d65be45': {'name': 'Behind Bars in Brooklyn',
#   'location': {'address': '610 5th Ave',
#    'lat': 40.663826,
#    'lng': -73.991132,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.663826,
#      'lng': -73.991132},
#     {'label': 'entrance', 'lat': 40.663787, 'lng': -73.991068}],
#    'distance': 1164,
#    'postalCode': '11215',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['610 5th Ave', 'Brooklyn, NY 11215', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4a64bf8bf964a5209dc61fe3': {'name': 'Brooklyn Bicycles',
#   'location': {'address': '375 9th St',
#    'crossStreet': 'At 6th ave',
#    'lat': 40.668129,
#    'lng': -73.983886,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.668129,
#      'lng': -73.983886}],
#    'distance': 388,
#    'postalCode': '11215',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['375 9th St (At 6th ave)',
#     'Brooklyn, NY 11215',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4bc33e652a89ef3b4cb5f488': {'name': '9th Street Cycles',
#   'location': {'address': '375 9th St',
#    'crossStreet': '6th Ave & 9th St',
#    'lat': 40.66814312336656,
#    'lng': -73.98396854707498,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.66814312336656,
#      'lng': -73.98396854707498},
#     {'label': 'entrance', 'lat': 40.668231, 'lng': -73.983989}],
#    'distance': 393,
#    'postalCode': '11215',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['375 9th St (6th Ave & 9th St)',
#     'Brooklyn, NY 11215',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '5522ad41498e1ca4ccb9d3a4': {'name': 'Bicycle Habitat',
#   'location': {'address': '560 Vanderbilt',
#    'crossStreet': 'Dean And Bergen Streets',
#    'lat': 40.67989767084647,
#    'lng': -73.96813754157259,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.67989767084647,
#      'lng': -73.96813754157259},
#     {'label': 'entrance', 'lat': 40.679877, 'lng': -73.968246}],
#    'distance': 1488,
#    'postalCode': '11238',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['560 Vanderbilt (Dean And Bergen Streets)',
#     'Brooklyn, NY 11238',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4c13cc167f7f2d7f16b6df68': {'name': 'Rolling Orange Bikes',
#   'location': {'address': '269 Baltic St',
#    'crossStreet': 'Court St.',
#    'lat': 40.685674965531845,
#    'lng': -73.99396335496293,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.685674965531845,
#      'lng': -73.99396335496293}],
#    'distance': 2105,
#    'postalCode': '11201',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['269 Baltic St (Court St.)',
#     'Brooklyn, NY 11201',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '60379504'},
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4a58de9cf964a52014b81fe3': {'name': 'Ride Brooklyn',
#   'location': {'address': '468 Bergen St',
#    'crossStreet': 'btw 5th & Flatbush',
#    'lat': 40.680827751109206,
#    'lng': -73.97587633668071,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.680827751109206,
#      'lng': -73.97587633668071}],
#    'distance': 1254,
#    'postalCode': '11217',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['468 Bergen St (btw 5th & Flatbush)',
#     'Brooklyn, NY 11217',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '81274827'},
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4adb82b0f964a5206a2821e3': {'name': "Dixon's Bike Shop",
#   'location': {'address': '792 Union St',
#    'crossStreet': 'btw 6th and 7th Ave.',
#    'lat': 40.67481316295679,
#    'lng': -73.97635580511307,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.67481316295679,
#      'lng': -73.97635580511307}],
#    'distance': 617,
#    'postalCode': '11215',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['792 Union St (btw 6th and 7th Ave.)',
#     'Brooklyn, NY 11215',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4edf9b979a52cb6e8f86f65f': {'name': 'Motorcycle Works',
#   'location': {'address': '316 Carrol St',
#    'lat': 40.682942410970725,
#    'lng': -73.99434028256678,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.682942410970725,
#      'lng': -73.99434028256678}],
#    'distance': 1881,
#    'postalCode': '07004',
#    'cc': 'US',
#    'state': 'New York',
#    'country': 'United States',
#    'formattedAddress': ['316 Carrol St', 'NY 07004', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4f6ce0bfe4b0738fb1ae131c': {'name': 'Fulton Bikes, Clinton Hill',
#   'location': {'address': '997 Fulton St',
#    'lat': 40.6827061726901,
#    'lng': -73.96308049563686,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.6827061726901,
#      'lng': -73.96308049563686},
#     {'label': 'entrance', 'lat': 40.682787, 'lng': -73.963027}],
#    'distance': 2010,
#    'postalCode': '11238',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['997 Fulton St',
#     'Brooklyn, NY 11238',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4a0f6f89f964a52067761fe3': {'name': 'R&A Cycles',
#   'location': {'address': '105 5th Ave',
#    'crossStreet': 'at Baltic St.',
#    'lat': 40.67945117084359,
#    'lng': -73.97831946452223,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.67945117084359,
#      'lng': -73.97831946452223},
#     {'label': 'entrance', 'lat': 40.679398, 'lng': -73.978298}],
#    'distance': 1061,
#    'postalCode': '11217',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['105 5th Ave (at Baltic St.)',
#     'Brooklyn, NY 11217',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '81434078'},
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4f63b594e4b0cded5bc9a3f2': {'name': 'Bike Smith',
#   'location': {'address': '149 Smith St',
#    'crossStreet': 'Bergen Street',
#    'lat': 40.686646384678895,
#    'lng': -73.99046072286392,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.686646384678895,
#      'lng': -73.99046072286392}],
#    'distance': 2052,
#    'postalCode': '11201',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['149 Smith St (Bergen Street)',
#     'Brooklyn, NY 11201',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '88836308'},
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '545a7751498e98a4baff1450': {'name': 'BIkeSmith- Gowanus',
#   'location': {'address': '530 3rd Ave',
#    'crossStreet': '12th street',
#    'lat': 40.66948699951172,
#    'lng': -73.99315643310547,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.66948699951172,
#      'lng': -73.99315643310547}],
#    'distance': 1112,
#    'postalCode': '11215',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['530 3rd Ave (12th street)',
#     'Brooklyn, NY 11215',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '531b8601498eafed3fa40723': {'name': 'Vaxmoto',
#   'location': {'address': '339 Butler St',
#    'crossStreet': '4th Ave',
#    'lat': 40.680652,
#    'lng': -73.98204,
#    'labeledLatLngs': [{'label': 'display', 'lat': 40.680652, 'lng': -73.98204},
#     {'label': 'entrance', 'lat': 40.680387, 'lng': -73.982214}],
#    'distance': 1198,
#    'postalCode': '11217',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['339 Butler St (4th Ave)',
#     'Brooklyn, NY 11217',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4fa6b1efe4b08e1f89c4550f': {'name': 'Excelsior Bike Shop',
#   'location': {'address': '694 Franklin Ave',
#    'crossStreet': 'Prospect Pl.',
#    'lat': 40.67481316264369,
#    'lng': -73.95545388815,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.67481316264369,
#      'lng': -73.95545388815},
#     {'label': 'entrance', 'lat': 40.674745, 'lng': -73.956628}],
#    'distance': 2140,
#    'postalCode': '11238',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['694 Franklin Ave (Prospect Pl.)',
#     'Brooklyn, NY 11238',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4e32ea5e7d8bf5432e419965': {'name': 'Dog Day Cyclery',
#   'location': {'address': '115 Van Brunt St',
#    'crossStreet': 'Union Street',
#    'lat': 40.68465221514292,
#    'lng': -74.00522101996955,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.68465221514292,
#      'lng': -74.00522101996955},
#     {'label': 'entrance', 'lat': 40.684658, 'lng': -74.005226}],
#    'distance': 2682,
#    'postalCode': '11231',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['115 Van Brunt St (Union Street)',
#     'Brooklyn, NY 11231',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718038',
#   'hasPerk': False},
#  '4b4c1188f964a520daad26e3': {'name': "Roy's Sheepshead Cycle",
#   'location': {'address': '2679 Coney Island Ave',
#    'lat': 40.591222952460555,
#    'lng': -73.9603264776867,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.591222952460555,
#      'lng': -73.9603264776867},
#     {'label': 'entrance', 'lat': 40.591225, 'lng': -73.960464}],
#    'distance': 2802,
#    'postalCode': '11235',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['2679 Coney Island Ave',
#     'Brooklyn, NY 11235',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '225506084'},
#   'referralId': 'v-1598718039',
#   'hasPerk': False},
#  '4e7e7e4c46906788c6bd00d2': {'name': 'Autobot',
#   'location': {'lat': 40.59545138670796,
#    'lng': -73.99987815125853,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.59545138670796,
#      'lng': -73.99987815125853}],
#    'distance': 1912,
#    'cc': 'US',
#    'state': 'New York',
#    'country': 'United States',
#    'formattedAddress': ['New York', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718039',
#   'hasPerk': False},
#  '50855b73e4b03db177fee92c': {'name': 'Spring Creek Bikes',
#   'location': {'lat': 40.65803930797783,
#    'lng': -73.87162858209753,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.65803930797783,
#      'lng': -73.87162858209753}],
#    'distance': 905,
#    'postalCode': '11208',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['Brooklyn, NY 11208', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718039',
#   'hasPerk': False},
#  '51840036498e9f0a3d468438': {'name': 'Talent Cycles',
#   'location': {'address': '502 W 139th St',
#    'crossStreet': 'Between Amsterdam & Hamilton Terrace',
#    'lat': 40.82144,
#    'lng': -73.950766,
#    'labeledLatLngs': [{'label': 'display', 'lat': 40.82144, 'lng': -73.950766},
#     {'label': 'entrance', 'lat': 40.821498, 'lng': -73.950728}],
#    'distance': 758,
#    'postalCode': '10031',
#    'cc': 'US',
#    'neighborhood': 'Hamilton Heights',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['502 W 139th St (Between Amsterdam & Hamilton Terrace)',
#     'New York, NY 10031',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718039',
#   'hasPerk': False},
#  '4f7f5369e4b0a95e41e8a630': {'name': 'Pedal Universe',
#   'location': {'lat': 40.820086794703926,
#    'lng': -73.94020423884278,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.820086794703926,
#      'lng': -73.94020423884278}],
#    'distance': 330,
#    'postalCode': '10030',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['New York, NY 10030', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718039',
#   'hasPerk': False},
#  '531e328b498e2748cc17cd2c': {'name': 'JS Cycle',
#   'location': {'address': '1842 Adam Clayton Powell Jr Blvd',
#    'crossStreet': '112th St.',
#    'lat': 40.80059669804809,
#    'lng': -73.9547038078308,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.80059669804809,
#      'lng': -73.9547038078308}],
#    'distance': 2173,
#    'postalCode': '10026',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['1842 Adam Clayton Powell Jr Blvd (112th St.)',
#     'New York, NY 10026',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718039',
#   'hasPerk': False},
#  '4f96620b754af8efd428196a': {'name': 'Tambal Ban Cak Ropik',
#   'location': {'address': '1620 Amsterdam Ave. W. 100th St.',
#    'lat': 40.821998596191406,
#    'lng': -73.95014953613281,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.821998596191406,
#      'lng': -73.95014953613281}],
#    'distance': 748,
#    'postalCode': '10031',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['1620 Amsterdam Ave. W. 100th St.',
#     'New York, NY 10031',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718039',
#   'hasPerk': False},
#  '4c28ecbd360cef3b2a2ebedc': {'name': 'CCNY Starbucks',
#   'location': {'address': 'NAC Plaza / Marshak Science Building',
#    'crossStreet': 'at CCNY',
#    'lat': 40.823632880508285,
#    'lng': -73.94580106689695,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.823632880508285,
#      'lng': -73.94580106689695}],
#    'distance': 669,
#    'postalCode': '10032',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['NAC Plaza / Marshak Science Building (at CCNY)',
#     'New York, NY 10032',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718039',
#   'hasPerk': False},
#  '4be2017dae55a593185f5c62': {'name': 'Junior Bicycle Shop',
#   'location': {'address': '1820 Amsterdam Ave.',
#    'crossStreet': 'W. 150th St.',
#    'lat': 40.825409243860484,
#    'lng': -73.94562143062798,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.825409243860484,
#      'lng': -73.94562143062798}],
#    'distance': 853,
#    'postalCode': '10031',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['1820 Amsterdam Ave. (W. 150th St.)',
#     'New York, NY 10031',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718039',
#   'hasPerk': False},
#  '59c1c511419a9e3dcde1e85d': {'name': 'Citi Bike Station',
#   'location': {'address': 'Park Avenue & 118th Street',
#    'crossStreet': 'Park Avenue',
#    'lat': 40.800487,
#    'lng': -73.941931,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.800487,
#      'lng': -73.941931}],
#    'distance': 1951,
#    'postalCode': '10035',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['Park Avenue & 118th Street (Park Avenue)',
#     'New York, NY 10035',
#     'United States']},
#   'categories': [{'id': '4e4c9077bd41f78e849722f9',
#     'name': 'Bike Rental / Bike Share',
#     'pluralName': 'Bike Rentals / Bike Shares',
#     'shortName': 'Bike',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718039',
#   'hasPerk': False},
#  '5185901e498e4754c2ef6579': {'name': 'Harlem Bike Doctors Rent/Repair',
#   'location': {'lat': 40.805602,
#    'lng': -73.942329,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.805602,
#      'lng': -73.942329}],
#    'distance': 1381,
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['New York, NY', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718039',
#   'hasPerk': False},
#  '51e47166498eded906b3ae15': {'name': 'Velocissimo',
#   'location': {'lat': 40.80068,
#    'lng': -73.955071,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.80068,
#      'lng': -73.955071}],
#    'distance': 2179,
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['New York, NY', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718039',
#   'hasPerk': False},
#  '4f9c36c8e4b0609168b20358': {'name': 'Bike Doctor NYC',
#   'location': {'lat': 40.81400865989977,
#    'lng': -73.94364271955618,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.81400865989977,
#      'lng': -73.94364271955618}],
#    'distance': 447,
#    'postalCode': '10030',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['New York, NY 10030', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718039',
#   'hasPerk': False},
#  '4f075a56e4b0e890796f2489': {'name': 'Fast Boy Cycles',
#   'location': {'address': '545 Manhattan Ave',
#    'lat': 40.809331,
#    'lng': -73.953975,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.809331,
#      'lng': -73.953975},
# ...
#     'name': 'Thrift / Vintage Store',
#     'pluralName': 'Thrift / Vintage Stores',
#     'shortName': 'Thrift / Vintage',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718065',
#   'hasPerk': False},
#  '4d4c8ad7e1ec6dcbcc9fda75': {'name': 'Special Delivery',
#   'location': {'address': 'Houston',
#    'lat': 40.727425,
#    'lng': -74.000749,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.727425,
#      'lng': -74.000749}],
#    'distance': 2396,
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['Houston', 'New York, NY', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718065',
#   'hasPerk': False},
#  '504cae0ee4b006c4365868e8': {'name': 'Jersey City Tour de Honor',
#   'location': {'lat': 40.71684658579805,
#    'lng': -74.03916658709201,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.71684658579805,
#      'lng': -74.03916658709201}],
#    'distance': 2167,
#    'postalCode': '07302',
#    'cc': 'US',
#    'city': 'Jersey City',
#    'state': 'NJ',
#    'country': 'United States',
#    'formattedAddress': ['Jersey City, NJ 07302', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718066',
#   'hasPerk': False},
#  '4bbd163b078095215431da91': {'name': 'Peak Mountain Bike Pro Shop',
#   'location': {'address': '42-42 235th St',
#    'lat': 40.76764526026922,
#    'lng': -73.74779994876785,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.76764526026922,
#      'lng': -73.74779994876785}],
#    'distance': 1075,
#    'postalCode': '11363',
#    'cc': 'US',
#    'city': 'Douglaston',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['42-42 235th St',
#     'Douglaston, NY 11363',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718067',
#   'hasPerk': False},
#  '4c6c52f5f2846dcb849b62e9': {'name': 'Trackstar',
#   'location': {'address': '518 E 11th St',
#    'lat': 40.727877,
#    'lng': -73.98097299999999,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.727877,
#      'lng': -73.98097299999999},
#     {'label': 'entrance', 'lat': 40.727975, 'lng': -73.980901}],
#    'distance': 1636,
#    'postalCode': '10009',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['518 E 11th St',
#     'New York, NY 10009',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718071',
#   'hasPerk': False},
#  '4c7add0a794e224ba1fc6928': {'name': 'Twin Bicycle',
#   'location': {'address': '75-20 Metropolitan Ave',
#    'lat': 40.71307954895426,
#    'lng': -73.87683116306222,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.71307954895426,
#      'lng': -73.87683116306222}],
#    'distance': 1615,
#    'postalCode': '11379',
#    'cc': 'US',
#    'city': 'Middle Village',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['75-20 Metropolitan Ave',
#     'Middle Village, NY 11379',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718072',
#   'hasPerk': False},
#  '4dc6c61381dc60ffd7766eae': {'name': 'The Red Hook Office',
#   'location': {'address': '70 Van Dyke St',
#    'crossStreet': 'at Richards St.',
#    'lat': 40.67470932006836,
#    'lng': -74.01293182373047,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.67470932006836,
#      'lng': -74.01293182373047}],
#    'distance': 1240,
#    'postalCode': '11231',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['70 Van Dyke St (at Richards St.)',
#     'Brooklyn, NY 11231',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718075',
#   'hasPerk': False},
#  '50898ddfe4b0499bc5645799': {'name': 'Papillionnaire Bicycles',
#   'location': {'address': '390 Van Brunt St',
#    'lat': 40.676747,
#    'lng': -74.013871,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.676747,
#      'lng': -74.013871}],
#    'distance': 1225,
#    'postalCode': '11231',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['390 Van Brunt St',
#     'Brooklyn, NY 11231',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718075',
#   'hasPerk': False},
#  '4b6d7f1df964a5205b782ce3': {'name': 'Bamboo Bike Studio',
#   'location': {'address': '201 Richards St',
#    'crossStreet': 'at Coffey St',
#    'lat': 40.67491912841797,
#    'lng': -74.01262664794922,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.67491912841797,
#      'lng': -74.01262664794922}],
#    'distance': 1206,
#    'postalCode': '11231',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['201 Richards St (at Coffey St)',
#     'Brooklyn, NY 11231',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718075',
#   'hasPerk': False},
#  '4f400eb5e4b0102f0d18b2a4': {'name': 'Gage + DeSoto',
#   'location': {'address': '70 Van Dyke St',
#    'lat': 40.674681,
#    'lng': -74.012959,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.674681,
#      'lng': -74.012959},
#     {'label': 'entrance', 'lat': 40.674629, 'lng': -74.013019}],
#    'distance': 1243,
#    'postalCode': '11231',
#    'cc': 'US',
#    'city': 'Brooklyn',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['70 Van Dyke St',
#     'Brooklyn, NY 11231',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718075',
#   'hasPerk': False},
#  '4fe60fa4e4b09198fdc2f2d8': {'name': 'Bicycle Rentals',
#   'location': {'lat': 40.765092776477175,
#    'lng': -73.98771184601551,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.765092776477175,
#      'lng': -73.98771184601551}],
#    'distance': 579,
#    'postalCode': '10019',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['New York, NY 10019', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718076',
#   'hasPerk': False},
#  '53446ceb11d209386275228e': {'name': 'Martone Cycling',
#   'location': {'lat': 40.75957718087501,
#    'lng': -73.98884242671608,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.75957718087501,
#      'lng': -73.98884242671608}],
#    'distance': 1164,
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['New York, NY', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718076',
#   'hasPerk': False},
#  '4ed576b5f5b975def5d7bffe': {'name': 'Sons Of Anarchy Watchers International',
#   'location': {'lat': 40.78666,
#    'lng': -73.848132,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.78666,
#      'lng': -73.848132}],
#    'distance': 757,
#    'postalCode': '11370',
#    'cc': 'US',
#    'city': 'East Elmhurst',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['East Elmhurst, NY 11370', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718080',
#   'hasPerk': False},
#  '51a3a675498ef9890db36be1': {'name': 'Citi Bike Station',
#   'location': {'address': 'E 5th St & Ave C',
#    'lat': 40.723063989870155,
#    'lng': -73.98014768816418,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.723063989870155,
#      'lng': -73.98014768816418}],
#    'distance': 2698,
#    'cc': 'US',
#    'neighborhood': 'Alphabet City',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['E 5th St & Ave C', 'New York, NY', 'United States']},
#   'categories': [{'id': '4e4c9077bd41f78e849722f9',
#     'name': 'Bike Rental / Bike Share',
#     'pluralName': 'Bike Rentals / Bike Shares',
#     'shortName': 'Bike',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718083',
#   'hasPerk': False},
#  '599361bb018cbb601d6cee99': {'name': 'Maglia Rosa NYC',
#   'location': {'lat': 40.65672377402883,
#    'lng': -74.00547588293178,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.65672377402883,
#      'lng': -74.00547588293178}],
#    'distance': 2278,
#    'postalCode': '11232',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['New York, NY 11232', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'delivery': {'id': '2034106',
#    'url': 'https://www.seamless.com/menu/maglia-rosa-nyc-920-3rd-ave-brooklyn/2034106?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2034106',
#    'provider': {'name': 'seamless',
#     'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#      'sizes': [40, 50],
#      'name': '/delivery_provider_seamless_20180129.png'}}},
#   'referralId': 'v-1598718084',
#   'hasPerk': False},
#  '4bacb985f964a52012073be3': {'name': 'Street Kings NYC',
#   'location': {'address': '303 W 42nd St',
#    'crossStreet': 'btw 8th Ave. & 9th Ave.',
#    'lat': 40.75756094557571,
#    'lng': -73.98962966225163,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.75756094557571,
#      'lng': -73.98962966225163}],
#    'distance': 2279,
#    'postalCode': '10036',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['303 W 42nd St (btw 8th Ave. & 9th Ave.)',
#     'New York, NY 10036',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d103951735',
#     'name': 'Clothing Store',
#     'pluralName': 'Clothing Stores',
#     'shortName': 'Apparel',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#      'suffix': '.png'},
#     'primary': True}],
#   'venuePage': {'id': '85690020'},
#   'referralId': 'v-1598718085',
#   'hasPerk': False},
#  '5027fe88e4b0db2acb1fb4ef': {'name': 'Metrobicycles',
#   'location': {'lat': 40.76198309764995,
#    'lng': -73.99030585884952,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.76198309764995,
#      'lng': -73.99030585884952}],
#    'distance': 1793,
#    'postalCode': '10036',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['New York, NY 10036', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718085',
#   'hasPerk': False},
#  '5e8e49bc2aa1800008b0ac76': {'name': 'Rockaway Beach Cycles',
#   'location': {'lat': 40.584375,
#    'lng': -73.820079,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.584375,
#      'lng': -73.820079}],
#    'distance': 1809,
#    'postalCode': '11694',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['New York, NY 11694', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718086',
#   'hasPerk': False},
#  '4f94aff1e4b0242d625c8921': {'name': 'Bike Shop 4 US',
#   'location': {'lat': 40.790127,
#    'lng': -73.752637,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.790127,
#      'lng': -73.752637}],
#    'distance': 2480,
#    'postalCode': '11023',
#    'cc': 'US',
#    'city': 'Great Neck',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['Great Neck, NY 11023', 'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718088',
#   'hasPerk': False},
#  '4bc9f4013740b713bca15f65': {'name': 'The Bike Shop of Staten Island',
#   'location': {'address': '4026 Hylan Blvd',
#    'lat': 40.541308,
#    'lng': -74.146434,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.541308,
#      'lng': -74.146434},
#     {'label': 'entrance', 'lat': 40.541402, 'lng': -74.146561}],
#    'distance': 1110,
#    'postalCode': '10308',
#    'cc': 'US',
#    'city': 'Staten Island',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['4026 Hylan Blvd',
#     'Staten Island, NY 10308',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d115951735',
#     'name': 'Bike Shop',
#     'pluralName': 'Bike Shops',
#     'shortName': 'Bike Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'referralId': 'v-1598718088',
#   'hasPerk': False}}

# %% [markdown]
# We now build a dataframe that contains all necessary information to count the number of bike shops in a zip code area.

# %%
# We now construct a dataframe that contains all necesarry information to assign bike shops to zip code areas
bikeshop_df = pd.DataFrame(columns = ['Id', 'Name', 'Zip Code', 'Lat', 'Long'])

# Function to check if the dict entry contains zip code information
def check_pc(location):
    if 'postalCode' in location:
        return location['postalCode']
    else:
        return "Error"
# Build a dataframe from the dict
for i in bikeshops_dict:
    bikeshop_df = bikeshop_df.append({'Id' : i, 'Zip Code': check_pc(bikeshops_dict[i]['location']), 
                                      'Name': bikeshops_dict[i]['name'],
                                      'Lat' : bikeshops_dict[i]['location']['lat'],
                                      'Long' : bikeshops_dict[i]['location']['lng']}, ignore_index=True)

# %%
bikeshop_df.head()
# Out:
#                          Id                       Name Zip Code        Lat  \
# 0  4bd7372b0b779c74f8ad04a0        County Cycle Center    10704  40.903306
# 1  50608454e4b0fc173099b6d5  Bronx River Bicycle Works    10550  40.911275
# 2  4bf5525594af2d7fb78c3b72      Kim's Motorcycle Corp    10704  40.905510
# 3  511fd14be4b0b9b40101898a                  bike shop    10466  40.889973
# 4  4d60403aef378cfaf9147ba6            Arrow Cycle Inc    10466  40.890157
#
#         Long
# 0 -73.865639
# 1 -73.845048
# 2 -73.870253
# 3 -73.859406
# 4 -73.859414

# %% [markdown]
# Some entries do not contain zip code information. We resort to the uszipcode library to map a zip code to these bike shops based on their coordinates.

# %%
# Use the uszipcode library to find missing postal codes

# Iterate over the bikeshop dataframe
for index, row in bikeshop_df.loc[bikeshop_df['Zip Code'] == 'Error'].iterrows():
    a = search.by_coordinates(row['Lat'], row['Long'], returns = 1)
    a = a[0].to_dict()
    bikeshop_df.loc[index, 'Zip Code'] = a['zipcode']

# %% [markdown]
# We can now count the number of bike shops in each zip code area.

# %%
# Build a Dataframe that shows the number of bike shops in each zip code area
bikeshop_count_df = bikeshop_df.groupby(['Zip Code'])[['Name']].count()
bikeshop_count_df.reset_index(inplace = True)
bikeshop_count_df.rename(columns = {'Name':'Bike Shops'}, inplace = True)

# %%
print("Number of zip code areas that have a bike shop: " + 
     str(bikeshop_count_df['Zip Code'].count()))
print("Total number of bike shops: " + str(bikeshop_count_df['Bike Shops'].sum()))
bikeshop_count_df.sort_values(by = 'Bike Shops', ascending = False).head(10)
# Out:
# Number of zip code areas that have a bike shop: 123
# Total number of bike shops: 373
#    Zip Code  Bike Shops
# 6     10002          16
# 74    11211          16
# 69    11206          12
# 16    10019          10
# 12    10013           9
# 78    11215           9
# 85    11222           8
# 9     10009           8
# 32    10036           8
# 83    11220           7

# %% [markdown]
# We can now merge this resulting dataframe with the original dataframe

# %%
# Merge the number of bikeshops in each zip code area with the original dataframe
ny_df2 = ny_df.merge(bikeshop_count_df, on = 'Zip Code', how = 'left')

# Replace all missing values with 0
ny_df2['Bike Shops'].fillna(value = 0, inplace = True)

# Change data type of bike shops column
ny_df2[['Bike Shops']] = ny_df2[['Bike Shops']].astype('int64')

# Show top ten zip code areas
ny_df2.sort_values(by = 'Bike Shops', ascending = False).head(10)
# Out:
#     Zip Code           County    Lat   Long  Area  Bike Shops
# 60     10002  New York County  40.72 -73.99  0.88          16
# 81     11211     Kings County  40.71 -73.95  2.30          16
# 31     11206     Kings County  40.70 -73.94  1.43          12
# 168    10019  New York County  40.77 -73.99  0.68          10
# 6      11215     Kings County  40.67 -73.98  2.18           9
# 112    10013  New York County  40.72 -74.01  0.55           9
# 89     10036  New York County  40.76 -73.99  0.44           8
# 11     10009  New York County  40.73 -73.98  0.62           8
# 107    11222     Kings County  40.73 -73.95  1.52           8
# 83     11220     Kings County  40.64 -74.02  1.79           7

# %%
# Print the number of zip code areas in NYC that have a bike shop
print("Number of zip code areas that have a bike shop: " + 
     str(ny_df2['Zip Code'].loc[ny_df2['Bike Shops'] != 0].count()))

# Print the total number of bike shops in the combined dataframe
print("Total number of bike shops: " + str(ny_df2['Bike Shops'].sum()))
# Out:
# Number of zip code areas that have a bike shop: 110
# Total number of bike shops: 347

# %% [markdown]
# It is noteworthy that the above numbers are smaller after merging the dataframe that counted the number of bike shops with our original dataframe. This is because our foursquare api call results (which were based on cordinates and a specified radius) included bike shops located outside of NYC. After merging, these entries dissappear.
#
# ## ACS API calls
#
# The next two cells are used to get demographic and economic data for all NYC zip code areas.

# %%
# Get Census Data from the ACS:
# - Population: Inhabitants for each zip code area
# - Income: Average income in each zip code area 
# - Bike to work: Number of inhabitants that use a bike to get to work

# Define API key and dataframe
acs_key = ''
ny_acs_df = pd.DataFrame(columns = ['Zip Code', 'Population', 'Income', 'Bike to work'])

# Loop over all zip codes
for index, row in ny_df2.iterrows():
    # API URL. Keywords are B01003_001E, B19013_001E and B08006_014E
    acs_url = ('https://api.census.gov/data/2018/acs/acs5?' +
    'get=B01003_001E,B19013_001E,B08006_014E&for=zip%20code%20tabulation%20area:' + row['Zip Code']) + '&key=' + acs_key
    
    # Make API call
    acs_page = requests.get(acs_url, allow_redirects=False, timeout=10)
    acs_page = acs_page.text
    # The result page is a string in the form of a nested list.
    # Use the ast extension to turn the string into an actual list
    try:
        acs_result = ast.literal_eval(acs_page)
    # Handle errors    
    except SyntaxError:
        print(row['Zip Code'] + ':' + acs_page + '\n')
        acs_b_result = [['empty'],['unknown','unknown', 'unknown']]
            
    # Extract relevant variables from result list
    population_acs = acs_result[1][0]
    income_acs = acs_result[1][1]
    biketowork_acs = acs_result[1][2]
    
    # Append the dataframe
    ny_acs_df = ny_acs_df.append({'Zip Code':row['Zip Code'], 'Population' : population_acs,
                                  'Income':income_acs, 'Bike to work': biketowork_acs}, ignore_index = True)

# %%
# Get Business Data from the ACS:
# Payroll: Total salaries paid in a zip code
# Employees: Number of employees in a zip code


# Define API key and dataframe
acs_key = ''
ny_acs_b_df = pd.DataFrame(columns = ['Zip Code', 'Employees', 'Payroll'])

# Loop over all zip codes
for index, row in ny_df2.iterrows():
    # API URL. Keywords are EMP and PAYANN
    acs_b_url = 'https://api.census.gov/data/2018/zbp?get=EMP,PAYANN&for=zipcode:' + row['Zip Code'] + '&key=' + acs_key
    
    # Make API call
    acs_b_page = requests.get(acs_b_url, allow_redirects=False, timeout=10)
    acs_b_page = acs_b_page.text
    # The result page is a string in the form of a nested list.
    # Use the ast extension to turn the string into an actual list
    try:
        acs_b_result = ast.literal_eval(acs_b_page)
    # Handle errors  
    except SyntaxError:
        print(row['Zip Code'] + ':' + acs_b_page + '\n')
        acs_b_result = [['empty'],['unknown','unknown']]
        
    # Extract relevant variables from result list
    employees_acs = acs_b_result[1][0]
    payroll_acs = acs_b_result[1][1]
    
    # Append dataframe
    ny_acs_b_df = ny_acs_b_df.append({'Zip Code':row['Zip Code'], 'Employees':employees_acs,
                                      'Payroll':payroll_acs}, ignore_index = True)
# Out:
# 11424:
#
# 11425:

# %%
# Summary of errors
print(ny_acs_b_df.loc[ny_acs_b_df['Payroll'] == 'unknown'])
print(ny_acs_b_df.loc[ny_acs_df['Population'] == 'unknown'])
# Out:
#    Zip Code Employees  Payroll
# 26    11424   unknown  unknown
# 84    11425   unknown  unknown
# Empty DataFrame
# Columns: [Zip Code, Employees, Payroll]
# Index: []

# %%
# Safe all dataframes
ny_acs_df.to_csv('ny_acs')
ny_acs_b_df.to_csv('ny_acs_b')
ny_df2.to_csv('ny_df2')

# %% [markdown]
# This cell indicates the end of all API calls. We save the resulting dataframes. The data exploration, modelling and evaluation steps are shown in the second notebook.
